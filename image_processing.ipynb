# %%
import blue_sampler as blue

# %%
x = blue.im2points("zebra.jpg", N =50_000)
# Out:
# ✦ 2D blue-noise pipeline — sampling 50,000 points
# [Level 3 : N =  1852] done 2s
# [Level 2 : N =  5556] done 2s
# [Level 1 : N = 16668] done 4s
# [Level 0 : N = 50000] done 7s
# Done - To see result: blue.plot(x)
